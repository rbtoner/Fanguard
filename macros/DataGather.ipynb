# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import cleaners
import postGather
reload(postGather)
# Out:
# <module 'postGather' from '/Users/ruthtoner/CodingMacros/ProjectInsight/Fanguard/DataCollection/postGather.pyc'>

# %%
postGather.GeneratePosts("star-wars","sw",4,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... Total elapsed time (spoilers) = 110041049.0
# ...

# %%
postGather.GeneratePosts("age-of-ultron","aou",3,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
#  0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... Total elapsed time (spoilers) = 86134495.0
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... Total elapsed time (all posts) = 2787913.0
# Cleaning Spoiler text...
# Cleaning Regular text...
# Calculating counts..
# Cleaning Spoiler tags...
# Cleaning Regular tags...
# Copying over other stuff...
# Done generating trees.
# Starting Spoiler MySQL upload...
# Done...
# Starting Regular MySQL upload...
# Done...
# FINISHED

# %%
postGather.GeneratePosts("mad-max","madmax",3,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... Total elapsed time (spoilers) = 18459610.0
# 0... 20... 40... 60... 80... Total elapsed time (all posts) = 303505.0
# Cleaning Spoiler text...
# Cleaning Regular text...
# Calculating counts..
# Cleaning Spoiler tags...
# Cleaning Regular tags...
# Copying over other stuff...
# Done generating trees.
# Starting Spoiler MySQL upload...
# Done...
# Starting Regular MySQL upload...
# Done...
# FINISHED
# /Users/ruthtoner/anaconda/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
postGather.GeneratePosts("dai","dai",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... 880... 900... 920... 940... 960... 980... Total elapsed time (spoilers) = 49187493.0
# 0... Out of posts
# (GAP)
# 20... 40... 60... WARNING: 1441841541 < 1441842293; will later drop duplicates
# 80... WARNING: 1441830921 < 1441831147; will later drop duplicates
# WARNING: 1441825859 < 1441827477; will later drop duplicates
# WARNING: 1441780495 < 1441781315; will later drop duplicates
# WARNING: 1441774521 < 1441778945; will later drop duplicates
# WARNING: 1441772957 < 1441773776; will later drop duplicates
# WARNING: 1441769175 < 1441769194; will later drop duplicates
# 100... WARNING: 1441764316 < 1441766618; will later drop duplicates
# ...

# %%
postGather.GeneratePosts("undertale","utale",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... 880... 900... 920... 940... 960... 980... Total elapsed time (spoilers) = 6403248.0
# ...

# %%
postGather.GeneratePosts("life-is-strange","lis",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... Out of posts
# Total elapsed time (spoilers) = 30009954.0
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... WARNING: 1445327397 < 1445327518; will later drop duplicates
# WARNING: 1445326583 < 1445326651; will later drop duplicates
# 400... 420... WARNING: 1445316347 < 1445316384; will later drop duplicates
# WARNING: 1445315501 < 1445315534; will later drop duplicates
# WARNING: 1445314327 < 1445314364; will later drop duplicates
# WARNING: 1445314100 < 1445314172; will later drop duplicates
# WARNING: 1445313483 < 1445313495; will later drop duplicates
# 440... WARNING: 1445312167 < 1445312224; will later drop duplicates
# WARNING: 1445306451 < 1445306551; will later drop duplicates
# ...

# %%
postGather.GeneratePosts("game-of-thrones","got",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... Past date
# Total elapsed time (spoilers) = 93527343.0
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... WARNING: final 1431989993 < initial 1431966547
# 280... 300... 320... WARNING: final 1430873563 < initial 1426295409
# 340... 360... 380... 400... 420... 440... 460... WARNING: 1405980921 < 1411517194; will later drop duplicates
# 480... 500... 520... 540... 560... WARNING: final 1402885767 < initial 1402885740
# WARNING: final 1402885154 < initial 1402885140
# 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... WARNING: final 1399856767 < initial 1399851414
# ...

# %%
postGather.GeneratePosts("sherlock","slock",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... 880... 900... 920... 940... 960... 980... Total elapsed time (spoilers) = 61988646.0
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... WARNING: 1451683212 < 1451683222; will later drop duplicates
# 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... 880... 900... 920... 940... 960... 980... 1000... 1020... 1040... 1060... 1080... 1100... 1120... 1140... 1160... 1180... 1200... 1220... 1240... 1260... 1280... WARNING: 1389596253 < 1389596272; will later drop duplicates
# ...

# %%
postGather.GeneratePosts("hannibal","han",2,"/Users/ruthtoner/CodingMacros/ProjectInsight/myconfigs.cfg")
# Out:
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... 240... 260... 280... 300... 320... 340... 360... 380... 400... 420... 440... 460... 480... 500... 520... 540... 560... 580... 600... 620... 640... 660... 680... 700... 720... 740... 760... 780... 800... 820... 840... 860... 880... 900... 920... 940... 960... 980... Total elapsed time (spoilers) = 50160651.0
# 0... 20... 40... 60... 80... 100... 120... 140... 160... 180... 200... 220... WARNING: 1440745507 < 1440745932; will later drop duplicates
# WARNING: 1440744720 < 1440745066; will later drop duplicates
# WARNING: 1440744017 < 1440744281; will later drop duplicates
# 240... WARNING: 1440740541 < 1440740794; will later drop duplicates
# WARNING: 1440740200 < 1440740251; will later drop duplicates
# WARNING: 1440738401 < 1440738430; will later drop duplicates
# WARNING: 1440737821 < 1440737854; will later drop duplicates
# WARNING: 1440737266 < 1440737361; will later drop duplicates
# ...
